# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data = pd.read_csv('epl-allseasons-matchstats.csv')
data
# Out:
#        Season        Date        Referee     HomeTeam       AwayTeam FullTime  \
# 0     2010/11  2010-08-14         M Dean  Aston Villa       West Ham  HomeWin
# 1     2010/11  2010-08-14         P Dowd    Blackburn        Everton  HomeWin
# 2     2010/11  2010-08-14      S Attwell       Bolton         Fulham     Draw
# 3     2010/11  2010-08-14  M Clattenburg      Chelsea      West Brom  HomeWin
# 4     2010/11  2010-08-14       A Taylor   Sunderland     Birmingham     Draw
# ...       ...         ...            ...          ...            ...      ...
# 3795  2019/20  2020-07-26     M Atkinson    Leicester        Man Utd  AwayWin
# 3796  2019/20  2020-07-26       C Pawson     Man City        Norwich  HomeWin
# 3797  2019/20  2020-07-26       A Taylor    Newcastle      Liverpool  AwayWin
# 3798  2019/20  2020-07-26       P Bankes  Southampton  Sheffield Utd  HomeWin
# 3799  2019/20  2020-07-26       M Oliver     West Ham    Aston Villa     Draw
#
# ...

# %%
y=data['HomeGoals']
x1 =data['HomeGoalsHalfTime']
plt.scatter(x1,y)
plt.xlabel('HomeGoalsHalfTime', fontsize=20)
plt.ylabel('HomeGoals',fontsize=20)
plt.show()

# %%
x = sm.add_constant(x1)

# %%
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      HomeGoalsHalfTime   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     3340.
# Date:                Sat, 07 Jan 2023   Prob (F-statistic):               0.00
# Time:                        00:45:57   Log-Likelihood:                -3551.6
# No. Observations:                3800   AIC:                             7107.
# Df Residuals:                    3798   BIC:                             7120.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0034      0.016     -0.216      0.829      -0.034       0.027
# ...
